# %% [markdown]
# <a href="https://colab.research.google.com/github/iMan0405/Portfolio_DT_vs_AI/blob/main/Annotating_Images_for_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

matplotlib.rcParams['figure.figsize'] = (9.0, 9.0)

# %matplotlib inline

# %% [markdown]
# # Aktivlarni yuklab olish

# %%
def download_and_unzip(url, save_path):
    print(f"Yuklab olish va aktivlarni arxivdan chiqarish...", end="")

    #urllib fayli yordamida arxiv fayllarini yuklab olish
    urlretrieve(url, save_path)

    try:
        #zipfile faylidan foydalanib arxivdan yechish
        with ZipFile(save_path) as z:
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/48hboi1m4crv1tl/opencv_bootcamp_assets_NB3.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), f"opencv_bootcamp_assets_NB3.zip")

if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)
# Out:
# Yuklab olish va aktivlarni arxivdan chiqarish...Done

# %%
# rasmni o'qish
image = cv2.imread("Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)

#Asl rasmni ekranga chiqarish
plt.imshow(image[:, :, ::-1])

# %% [markdown]
# # Chiziq chizish

# %%
imageLine = image.copy()

cv2.line(imageLine, (200, 100), (400, 100), (0, 255, 255), thickness=5, lineType=cv2.LINE_AA);

plt.imshow(imageLine[:, :, ::-1])

# %% [markdown]
# # Doira chizish

# %%
imageCircle = image.copy()

cv2.circle(imageCircle, (600, 500), 100, (0, 0, 255), thickness=5, lineType=cv2.LINE_AA);

plt.imshow(imageCircle[:, :, ::-1])

# %% [markdown]
# # To'rtburchak chizish

# %%
imageRectangle = image.copy()

cv2.rectangle(imageRectangle, (500,100), (700, 600), (255, 0, 255), thickness=5, lineType=cv2.LINE_8)

plt.imshow(imageRectangle[:, :, ::-1])

# %%
imageText = image.copy()
text = "Test uchun foydalanildi"
fontScale = 2.3
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2

cv2.putText(imageText, text, (400, 700), fontFace, fontScale, fontColor, fontThickness, cv2.LINE_AA);

plt.imshow(imageText[:, :, ::-1])
