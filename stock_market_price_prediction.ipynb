# %% [markdown]
# <a href="https://colab.research.google.com/github/iMan0405/Portfolio_DT_vs_AI/blob/main/stock_market_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/EURUSD=X .csv')

# %%
df.head()
# Out:
#        Date      Open      High       Low     Close  Adj Close  Volume
# 0  1/1/2013  1.320132  1.322401  1.319592  1.320132   1.320132     0.0
# 1  1/2/2013  1.319784  1.329805  1.319435  1.319784   1.319784     0.0
# 2  1/3/2013  1.318392  1.318913  1.308900  1.318218   1.318218     0.0
# 3  1/4/2013  1.303101  1.306380  1.300052  1.303271   1.303271     0.0
# 4  1/7/2013  1.306848  1.309929  1.302060  1.306745   1.306745     0.0

# %%
viz = df.copy

# %% [markdown]
# #Data Preparation

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         4
# High         4
# Low          4
# Close        4
# Adj Close    4
# Volume       4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.shape
# Out:
# (2823, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2823 entries, 0 to 2826
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2823 non-null   object
#  1   Open       2823 non-null   float64
#  2   High       2823 non-null   float64
#  3   Low        2823 non-null   float64
#  4   Close      2823 non-null   float64
#  5   Adj Close  2823 non-null   float64
#  6   Volume     2823 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 176.4+ KB

# %%
df.describe().T
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Open       2823.0  1.161642  0.094688  0.959619  1.097171  1.133414  1.203861
# High       2823.0  1.165299  0.094482  0.967006  1.100455  1.136893  1.206928
# Low        2823.0  1.157919  0.094845  0.954016  1.092856  1.130224  1.200445
# Close      2823.0  1.161661  0.094689  0.959619  1.097105  1.133401  1.203761
# Adj Close  2823.0  1.161661  0.094689  0.959619  1.097105  1.133401  1.203761
# Volume     2823.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                 max
# Open       1.392990
# High       1.399110
# Low        1.391260
# Close      1.393088
# Adj Close  1.393088
# Volume     0.000000

# %%
train, test = train_test_split(df, test_size = 0.2)

# %%
test_pred = test.copy()

# %%
train.head(10)
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 1562  12/27/2018  1.136364  1.143432  1.135912  1.136131   1.136131     0.0
# 23      2/1/2013  1.361100  1.369300  1.358890  1.361100   1.361100     0.0
# 2748   7/14/2023  1.122347  1.124480  1.120611  1.122347   1.122347     0.0
# 1521  10/31/2018  1.134584  1.136015  1.131171  1.134636   1.134636     0.0
# 2046   11/4/2020  1.176457  1.176886  1.160766  1.176221   1.176221     0.0
# 404    7/21/2014  1.353198  1.354920  1.351470  1.353217   1.353217     0.0
# 2553  10/14/2022  0.975134  0.980383  0.970949  0.975134   0.975134     0.0
# 2291  10/13/2021  1.153097  1.157901  1.153057  1.153403   1.153403     0.0
# 2544   10/3/2022  0.979269  0.984426  0.975362  0.979269   0.979269     0.0
# 644    6/22/2015  1.136235  1.141000  1.131601  1.137294   1.137294     0.0

# %%
test.head(10)
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 998   10/28/2016  1.090001  1.095290  1.089752  1.090037   1.090037     0.0
# 202   10/10/2013  1.351936  1.354450  1.348951  1.352027   1.352027     0.0
# 16     1/23/2013  1.331558  1.335800  1.327401  1.331398   1.331398     0.0
# 2555  10/18/2022  0.984640  0.987362  0.981460  0.984640   0.984640     0.0
# 563    2/27/2015  1.120360  1.125000  1.117681  1.120536   1.120536     0.0
# 56     3/20/2013  1.286505  1.297230  1.286505  1.286389   1.286389     0.0
# 213   10/25/2013  1.380167  1.383000  1.377591  1.380396   1.380396     0.0
# 2160   4/13/2021  1.191214  1.195314  1.188430  1.191469   1.191469     0.0
# 939     8/8/2016  1.108770  1.110600  1.107371  1.108955   1.108955     0.0
# 1559  12/24/2018  1.137204  1.143838  1.137204  1.137281   1.137281     0.0

# %%
x_train = train[['Open', 'Low', 'Volume', 'Close']].values
x_test = test[['Open', 'Low', 'Volume', 'Close']].values

# %%
y_train = train['High'].values
y_test = test['High'].values

# %% [markdown]
# #Linear Regression

# %%
model_lnr = LinearRegression()
model_lnr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_lnr.predict(x_test)

# %%
result = model_lnr.predict([[1.090001, 1.089752, 1.090037, 1.090037]])
print(result)
# Out:
# [1.09522477]

# %% [markdown]
# #Model Evaluation

# %%
print("MSE",round(mean_squared_error(y_test,y_pred), 3))
print("RMSE",round(np.sqrt(mean_squared_error(y_test,y_pred)), 3))
print("MAE",round(mean_absolute_error(y_test,y_pred), 3))
print("MAPE",round(mean_absolute_percentage_error(y_test,y_pred), 3))
print("R2 Score : ", round(r2_score(y_test,y_pred), 3))
# Out:
# MSE 0.0
# RMSE 0.003
# MAE 0.002
# MAPE 0.002
# R2 Score :  0.999
