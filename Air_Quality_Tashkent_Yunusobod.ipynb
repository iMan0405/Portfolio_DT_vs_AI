# %% [markdown]
# <a href="https://colab.research.google.com/github/iMan0405/Portfolio_DT_vs_AI/blob/main/Air_Quality_Tashkent_Yunusobod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import warnings
import numpy as np
import pandas as pd
from math import pi
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from IPython.display import HTML,display

warnings.filterwarnings("ignore")

# %%
df_yunusobod = pd.read_csv("/content/drive/MyDrive/tashkent-yunusabad-air-quality.csv")

# %%
df_yunusobod.head()
# Out:
#        date  pm25  pm10  o3  so2  co
# 0  3/1/2024    99    21            4
# 1  3/2/2024    67    18            3
# 2  3/3/2024    62    23            5
# 3  3/4/2024    65    29        1   6
# 4  3/5/2024    66    41        2  12

# %%
df_yunusobod['date'].min(), df_yunusobod['date'].max()
# Out:
# ('1/1/2024', '9/9/2023')

# %%
# !pip install bar_chart_race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.3 MB/s eta 0:00:00
# ...

# %%
df_yunusobod['City'] = 'Yunusobod'
df_yunusobod.head()
# Out:
#        date  pm25  pm10  o3  so2  co       City
# 0  3/1/2024    99    21            4  Yunusobod
# 1  3/2/2024    67    18            3  Yunusobod
# 2  3/3/2024    62    23            5  Yunusobod
# 3  3/4/2024    65    29        1   6  Yunusobod
# 4  3/5/2024    66    41        2  12  Yunusobod

# %%
df_yunusobod.columns
# Out:
# Index(['date', ' pm25', ' pm10', ' o3', ' so2', ' co', 'City'], dtype='object')

# %%
fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3})

sns.lineplot(x="date", y=" co", data=df_yunusobod, color="b", label = 'Yunusobod')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '10.02.2023 dan 06.03.2024 gacha'
ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('CO LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3})

sns.lineplot(x="date", y=" pm25", data=df_yunusobod, color="y",label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('PM25 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3})

sns.lineplot(x="date", y=" pm10", data=df_yunusobod, color="g",label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('PM10 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 3})

sns.lineplot(x="date", y=" so2", data=df_yunusobod, color="r",label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('SO2 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 1})

sns.barplot(x="date", y=" o3", data=df_yunusobod, color="orange",label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('O3 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

# %%
df_yunusobod[' co'] = df_yunusobod[' co'].replace(' ', np.nan)
df_yunusobod = df_yunusobod.dropna(subset=[' co'])

# %%
df_yunusobod[' pm25'] = df_yunusobod[' pm25'].replace(' ', np.nan)
df_yunusobod = df_yunusobod.dropna(subset=[' pm25'])

# %%
df_yunusobod[' pm10'] = df_yunusobod[' pm10'].replace(' ', np.nan)
df_yunusobod = df_yunusobod.dropna(subset=[' pm10'])

# %%
df_yunusobod[' so2'] = df_yunusobod[' so2'].replace(' ', np.nan)
df_yunusobod = df_yunusobod.dropna(subset=[' so2'])

# %%
fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

sns.distplot(df_yunusobod[' co'], color="b", label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('CO LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

sns.distplot(df_yunusobod[' pm25'], color="y", label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('PM25 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

sns.distplot(df_yunusobod[' pm10'], color="g", label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('PM10 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

fig,ax = plt.subplots(figsize=(10, 5))
sns.despine(fig, left=True, bottom=True)
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

sns.distplot(df_yunusobod[' so2'], color="r", label = 'Yunusobod')

ax.set_xticklabels(ax.get_xticklabels(labels), rotation=30,ha="left")
plt.rcParams["xtick.labelsize"] = 15

ax.set_title('SO2 LEVEL FROM DIFFERENT CITIES')
ax.legend(fontsize = 14)

# %%
chart = sns.catplot(x="date", y=" co", data=df_yunusobod, height=14, aspect=1.6, kind="bar", palette="muted");
chart.set_xticklabels(rotation=45);

chart = sns.catplot(x="date", y=" pm25", data=df_yunusobod, height=14, aspect=1.6, kind="bar", palette="muted");
chart.set_xticklabels(rotation=45);

chart = sns.catplot(x="date", y=" pm10", data=df_yunusobod, height=14, aspect=1.6, kind="bar", palette="muted");
chart.set_xticklabels(rotation=45);

chart = sns.catplot(x="date", y=" so2", data=df_yunusobod, height=14, aspect=1.6, kind="bar", palette="muted");
chart.set_xticklabels(rotation=45);

# %%
df_yunusobod[[' pm25', ' pm10', ' co', ' so2', "date"]].style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# </style>
# <table id="T_49bea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49bea_level0_col0" class="col_heading level0 col0" > pm25</th>
#       <th id="T_49bea_level0_col1" class="col_heading level0 col1" > pm10</th>
#       <th id="T_49bea_level0_col2" class="col_heading level0 col2" > co</th>
#       <th id="T_49bea_level0_col3" class="col_heading level0 col3" > so2</th>
#       <th id="T_49bea_level0_col4" class="col_heading level0 col4" >date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49bea_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_49bea_row0_col0" class="data row0 col0" >65</td>
#       <td id="T_49bea_row0_col1" class="data row0 col1" >29</td>
#       <td id="T_49bea_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_49bea_row0_col3" class="data row0 col3" >1</td>
# ...
